# %% [raw]
# ---
# description: An example module purely for demonstrating the workings of nbdev
# output-file: hello.html
# title: hello
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(say_hello)
# Out:
# ---
#
# ### say_hello
#
# >      say_hello (to)
#
# Say hello to somebody

# %% [markdown]
# ## Examples

# %%
say_hello('Test')
# Out:
# 'Hello Test!'

# %% [markdown]
# ## Tests

# %%
assert say_hello('Batman') == 'Hello Batman!'

# %%
from fastcore.test import *

test_eq(say_hello('Robin'), 'Hello Robin!')
